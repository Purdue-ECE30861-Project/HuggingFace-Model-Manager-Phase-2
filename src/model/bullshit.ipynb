# %%
import botocore.session

# %%
session = botocore.session.get_session()

# %%
s3_client = session.create_client(
        's3',
        endpoint_url='http://localhost:9000',  # Replace with your MinIO endpoint
        aws_access_key_id='minio_access_key_123',
        aws_secret_access_key='minio_secret_key_password_456',
    )

# %%
response = s3_client.list_buckets()

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '18744AC5EAC0F9D6',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '379',
#    'content-type': 'application/xml',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18744AC5EAC0F9D6',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1253',
#    'x-ratelimit-remaining': '1253',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Sun, 02 Nov 2025 20:32:48 GMT'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'hfmm-artifact-storage',
#    'CreationDate': datetime.datetime(2025, 11, 2, 19, 16, 3, 191000, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'minio',
#   'ID': '02d6176db174dc93cb1b899f7c6078f08654445fe8cf1b6ce98d8855f66bdbf4'}}

# %%
s3_client.put_object(
                Bucket = "hfmm-artifact-storage",
                Key = f"a1",
                Body = bytes(0)
            )
# Out:
# {'ResponseMetadata': {'RequestId': '18744AC5F0D9C9A0',
#   'HostId': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'accept-ranges': 'bytes',
#    'content-length': '0',
#    'etag': '"d41d8cd98f00b204e9800998ecf8427e"',
#    'server': 'MinIO',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'Origin, Accept-Encoding',
#    'x-amz-checksum-crc32': 'AAAAAA==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-id-2': 'dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8',
#    'x-amz-request-id': '18744AC5F0D9C9A0',
#    'x-content-type-options': 'nosniff',
#    'x-ratelimit-limit': '1253',
#    'x-ratelimit-remaining': '1253',
#    'x-xss-protection': '1; mode=block',
#    'date': 'Sun, 02 Nov 2025 20:32:48 GMT'},
#   'RetryAttempts': 0},
#  'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#  'ChecksumCRC32': 'AAAAAA==',
#  'ChecksumType': 'FULL_OBJECT'}
